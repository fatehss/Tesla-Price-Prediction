# %%
#apikey = X8vGMLWCXtOxkRhrgABZGj3baiaKApAn
#secret = VG1FpQufkmHA1F3n

#https://towardsdatascience.com/collecting-data-from-the-new-york-times-over-any-period-of-time-3e365504004
#https://developer.nytimes.com/docs/articlesearch-product/1/overview

# %%
import os
import json
import time
import requests
import datetime
import dateutil
import pandas as pd
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ### Getting data month by month (10 at a time)

# %%
from dateutil.relativedelta import relativedelta
import pandas as pd
import datetime

end = datetime.date.today() + relativedelta(months=1)  # add one month to the end date
start = end - relativedelta(months=24)
months_in_range = [x.split(' ') for x in pd.date_range(start, end, freq='MS').strftime("%Y%m%d").tolist()]

months_in_range
# Out:
# [['20210701'],
#  ['20210801'],
#  ['20210901'],
#  ['20211001'],
#  ['20211101'],
#  ['20211201'],
#  ['20220101'],
#  ['20220201'],
#  ['20220301'],
#  ['20220401'],
#  ['20220501'],
#  ['20220601'],
#  ['20220701'],
#  ['20220801'],
#  ['20220901'],
#  ['20221001'],
#  ['20221101'],
#  ['20221201'],
#  ['20230101'],
#  ['20230201'],
#  ['20230301'],
#  ['20230401'],
#  ['20230501'],
#  ['20230601']]

# %% [markdown]
# ### Getting Data by Pages (in the span of 24 months)

# %%
def send_request(begin_date, end_date, page):
    '''Sends a request to the NYT Archive API for given date and page.'''
    
    url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'
    api_key = 'X8vGMLWCXtOxkRhrgABZGj3baiaKApAn'
    query = 'tesla'
    sort = 'best'

    # Send the request to the API
    response = requests.get(url, params={'api-key': api_key, 'q': query, 'begin_date': begin_date, 'end_date': end_date, 'sort': sort, 'page': page})
    time.sleep(15)
    return response




def parse_response(response, start, end):
    '''Parses and returns response as pandas data frame.'''
    data = {'headline': [],  
        'date': [], 
        'doc_type': [],
        'material_type': [],
        'section': [],
        'keywords': []}
    
    articles = response.json()['response']['docs'] 
    for article in articles: # For each article, make sure it falls within our date range
        
        date = dateutil.parser.parse(article['pub_date']).date()
        data['date'].append(date)
        data['headline'].append(article['headline']['main']) 
        if 'section' in article:
            data['section'].append(article['section_name'])
        else:
            data['section'].append(None)
        data['doc_type'].append(article['document_type'])
        if 'type_of_material' in article: 
            data['material_type'].append(article['type_of_material'])
        else:
            data['material_type'].append(None)
        keywords = [keyword['value'] for keyword in article['keywords'] if keyword['name'] == 'subject']
        data['keywords'].append(keywords)
    return pd.DataFrame(data) 


def get_data(start, end):
    '''Sends and parses request/response to/from NYT Archive API for given date range.'''
    total = 0
    print('Date range: ' + str(start) + ' to ' + str(end))
    if not os.path.exists('headlines'):
        os.mkdir('headlines_pages')
    page = 5
    while True:
        response = send_request(start, end, page)
        if response.status_code != 200:
            print('Error:', response.json()['fault']['faultstring'])
            break
        df = parse_response(response, start, end)
        if len(df) == 0:
            break
        total += len(df)
        df.to_csv('headlines_pages/' + start + '-' + end + '_page' + str(page) + '.csv', index=False)
        print('Saving headlines/' + start + '-' + end + '_page' + str(page) + '.csv...')
        page += 1
    print('Number of articles collected: ' + str(total))

# %%
get_data(months_in_range[0][0],months_in_range[-1][0])
# Out:
# Date range: 20210701 to 20230601
# Saving headlines/20210701-20230601_page5.csv...
# Saving headlines/20210701-20230601_page6.csv...
# Saving headlines/20210701-20230601_page7.csv...
# Saving headlines/20210701-20230601_page8.csv...
# Saving headlines/20210701-20230601_page9.csv...
# Saving headlines/20210701-20230601_page10.csv...
# Saving headlines/20210701-20230601_page11.csv...
# Saving headlines/20210701-20230601_page12.csv...
# Saving headlines/20210701-20230601_page13.csv...
# Saving headlines/20210701-20230601_page14.csv...
# Saving headlines/20210701-20230601_page15.csv...
# Saving headlines/20210701-20230601_page16.csv...
# Saving headlines/20210701-20230601_page17.csv...
# Saving headlines/20210701-20230601_page18.csv...
# Saving headlines/20210701-20230601_page19.csv...
# Saving headlines/20210701-20230601_page20.csv...
# Saving headlines/20210701-20230601_page21.csv...
# Saving headlines/20210701-20230601_page22.csv...
# Saving headlines/20210701-20230601_page23.csv...
# Saving headlines/20210701-20230601_page24.csv...
# Saving headlines/20210701-20230601_page25.csv...
# Saving headlines/20210701-20230601_page26.csv...
# Saving headlines/20210701-20230601_page27.csv...
# Saving headlines/20210701-20230601_page28.csv...
# Saving headlines/20210701-20230601_page29.csv...
# Saving headlines/20210701-20230601_page30.csv...
# Saving headlines/20210701-20230601_page31.csv...
# Saving headlines/20210701-20230601_page32.csv...
# Saving headlines/20210701-20230601_page33.csv...
# Saving headlines/20210701-20230601_page34.csv...
# Saving headlines/20210701-20230601_page35.csv...
# Saving headlines/20210701-20230601_page36.csv...
# Saving headlines/20210701-20230601_page37.csv...
# Saving headlines/20210701-20230601_page38.csv...
# Saving headlines/20210701-20230601_page39.csv...
# Saving headlines/20210701-20230601_page40.csv...
# Saving headlines/20210701-20230601_page41.csv...
# Saving headlines/20210701-20230601_page42.csv...
# Saving headlines/20210701-20230601_page43.csv...
# Saving headlines/20210701-20230601_page44.csv...
# Saving headlines/20210701-20230601_page45.csv...
# Saving headlines/20210701-20230601_page46.csv...
# Saving headlines/20210701-20230601_page47.csv...
# Saving headlines/20210701-20230601_page48.csv...
# Saving headlines/20210701-20230601_page49.csv...
# Saving headlines/20210701-20230601_page50.csv...
# Saving headlines/20210701-20230601_page51.csv...
# Saving headlines/20210701-20230601_page52.csv...
# Saving headlines/20210701-20230601_page53.csv...
# Saving headlines/20210701-20230601_page54.csv...
# Saving headlines/20210701-20230601_page55.csv...
# Saving headlines/20210701-20230601_page56.csv...
# Saving headlines/20210701-20230601_page57.csv...
# Saving headlines/20210701-20230601_page58.csv...
# Saving headlines/20210701-20230601_page59.csv...
# Saving headlines/20210701-20230601_page60.csv...
# Saving headlines/20210701-20230601_page61.csv...
# Saving headlines/20210701-20230601_page62.csv...
# Saving headlines/20210701-20230601_page63.csv...
# Saving headlines/20210701-20230601_page64.csv...
# Saving headlines/20210701-20230601_page65.csv...
# Saving headlines/20210701-20230601_page66.csv...
# Saving headlines/20210701-20230601_page67.csv...
# Saving headlines/20210701-20230601_page68.csv...
# Saving headlines/20210701-20230601_page69.csv...
# Saving headlines/20210701-20230601_page70.csv...
# Saving headlines/20210701-20230601_page71.csv...
# Saving headlines/20210701-20230601_page72.csv...
# Saving headlines/20210701-20230601_page73.csv...
# Saving headlines/20210701-20230601_page74.csv...
# Saving headlines/20210701-20230601_page75.csv...
# Saving headlines/20210701-20230601_page76.csv...
# Saving headlines/20210701-20230601_page77.csv...
# Saving headlines/20210701-20230601_page78.csv...
# Saving headlines/20210701-20230601_page79.csv...
# Saving headlines/20210701-20230601_page80.csv...
# Saving headlines/20210701-20230601_page81.csv...
# Saving headlines/20210701-20230601_page82.csv...
# Saving headlines/20210701-20230601_page83.csv...
# Saving headlines/20210701-20230601_page84.csv...
# Saving headlines/20210701-20230601_page85.csv...
# Saving headlines/20210701-20230601_page86.csv...
# Saving headlines/20210701-20230601_page87.csv...
# Saving headlines/20210701-20230601_page88.csv...
# Saving headlines/20210701-20230601_page89.csv...
# Saving headlines/20210701-20230601_page90.csv...
# Saving headlines/20210701-20230601_page91.csv...
# Saving headlines/20210701-20230601_page92.csv...
# Saving headlines/20210701-20230601_page93.csv...
# Saving headlines/20210701-20230601_page94.csv...
# Saving headlines/20210701-20230601_page95.csv...
# Saving headlines/20210701-20230601_page96.csv...
# Saving headlines/20210701-20230601_page97.csv...
# Saving headlines/20210701-20230601_page98.csv...
# Saving headlines/20210701-20230601_page99.csv...
# Saving headlines/20210701-20230601_page100.csv...
# Saving headlines/20210701-20230601_page101.csv...
# Saving headlines/20210701-20230601_page102.csv...
# Saving headlines/20210701-20230601_page103.csv...
# Saving headlines/20210701-20230601_page104.csv...
# Saving headlines/20210701-20230601_page105.csv...
# Saving headlines/20210701-20230601_page106.csv...
# Saving headlines/20210701-20230601_page107.csv...
# Saving headlines/20210701-20230601_page108.csv...
# Saving headlines/20210701-20230601_page109.csv...
# Saving headlines/20210701-20230601_page110.csv...
# Saving headlines/20210701-20230601_page111.csv...
# Saving headlines/20210701-20230601_page112.csv...
# Saving headlines/20210701-20230601_page113.csv...
# Saving headlines/20210701-20230601_page114.csv...
# Saving headlines/20210701-20230601_page115.csv...
# Saving headlines/20210701-20230601_page116.csv...
# Saving headlines/20210701-20230601_page117.csv...
# Saving headlines/20210701-20230601_page118.csv...
# Saving headlines/20210701-20230601_page119.csv...
# Saving headlines/20210701-20230601_page120.csv...
# Saving headlines/20210701-20230601_page121.csv...
# Saving headlines/20210701-20230601_page122.csv...
# Saving headlines/20210701-20230601_page123.csv...
# Saving headlines/20210701-20230601_page124.csv...
# Saving headlines/20210701-20230601_page125.csv...
# Number of articles collected: 1209
