# %% [markdown]
# # Data Cleaning
#
# In this notebook, the goal is to preprocess the data so that it is more suitable for performing sentiment analysis. To this end, we aim to remove the "#" character from tweets as sometimes the following words can impact the sentiment.

# %% [markdown]
# ## Section 1: Removing non-english tweets
#
# In our dataset, we have 150k tweets available to us over the span of 7 months. Some of the tweets are not in english. Here, we aim to remove all non-english tweets using a ML model that can detect the language of a given input.

# %%
import pandas as pd
import numpy as np
from langdetect import detect
from pandarallel import pandarallel

# %%
tesla_df = pd.read_csv("tesla-tweets-updated.csv")

# %%
tesla_df.head()
# Out:
#                  Date & Time  \
# 0  April 10, 2022 at 07:44PM
# 1  April 10, 2022 at 07:45PM
# 2  April 10, 2022 at 07:45PM
# 3  April 10, 2022 at 07:45PM
# 4  April 10, 2022 at 07:45PM
#
#                                 Profile Picture Link      Twitter ID  \
# 0  http://pbs.twimg.com/profile_images/1512074518...  @Jessica1988kk
# 1  http://pbs.twimg.com/profile_ s/87878355348773...     @JotaGe2014
# 2  http://pbs.twimg.com/profile_images/9364223687...      @MmeCallas
# 3  http://pbs.twimg.com/profile_images/1463665918...        @BotSecx
# 4  http://pbs.twimg.com/profile_images/1116758599...          @agseh
#
#                                           Tweet Text  \
# 0  RT @invest_answers: Crypto news, #Bitcoin Whal...
# 1  #Tesla tiene récord de autos vendidos. Es impr...
# 2  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 3  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 4  RT @RupiReportero_: 🙆‍♂️🚘 Al que le robaron la...
#
#                                           Tweet Link
# 0  https://twitter.com/Jessica1988kk/status/15131...
# 1  https://twitter.com/JotaGe2014/status/15131737...
# 2  https://twitter.com/MmeCallas/status/151317374...
# 3  https://twitter.com/BotSecx/status/15131737626...
# 4  https://twitter.com/agseh/status/1513173864829...

# %%
def detect_en(text):
    try:
        return detect(text) == 'en'
    except:
        return False

# %%
#remove all rows that are not english 
pandarallel.initialize(progress_bar=True)
tesla_df = tesla_df[tesla_df['Tweet Text'].parallel_apply(detect_en)]
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=38000), Label(value='0 / 38000')))…

# %%
tesla_df.head()
# Out:
#                  Date & Time  \
# 0  April 10, 2022 at 07:44PM
# 2  April 10, 2022 at 07:45PM
# 3  April 10, 2022 at 07:45PM
# 5  April 10, 2022 at 07:45PM
# 6  April 10, 2022 at 07:45PM
#
#                                 Profile Picture Link      Twitter ID  \
# 0  http://pbs.twimg.com/profile_images/1512074518...  @Jessica1988kk
# 2  http://pbs.twimg.com/profile_images/9364223687...      @MmeCallas
# 3  http://pbs.twimg.com/profile_images/1463665918...        @BotSecx
# 5  http://pbs.twimg.com/profile_images/1507382366...      @ElTendies
# 6  http://pbs.twimg.com/profile_images/1355296710...  @LauraCory2013
#
#                                           Tweet Text  \
# 0  RT @invest_answers: Crypto news, #Bitcoin Whal...
# 2  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 3  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 5  RT @cb_doge: Tesla - A Trillion Dollar Company...
# 6  @elonmusk, few #chargingstations in my area. I...
#
#                                           Tweet Link
# 0  https://twitter.com/Jessica1988kk/status/15131...
# 2  https://twitter.com/MmeCallas/status/151317374...
# 3  https://twitter.com/BotSecx/status/15131737626...
# 5  https://twitter.com/ElTendies/status/151317393...
# 6  https://twitter.com/LauraCory2013/status/15131...

# %% [markdown]
# ## Section 2: Grouping by Week

# %%
#ATTENTION: two of the dates are in this form: day-month-year (with no timestamp)
#I just changed both to the other format with a timestamp of 12:00 am 
#The new csv is named "tesla-tweets-updated"
tesla_df['Date & Time'] = pd.to_datetime(tesla_df['Date & Time'], format='%B %d, %Y at %I:%M%p')
tesla_df.head()
# Out:
#           Date & Time                               Profile Picture Link  \
# 0 2022-04-10 19:44:00  http://pbs.twimg.com/profile_images/1512074518...
# 2 2022-04-10 19:45:00  http://pbs.twimg.com/profile_images/9364223687...
# 3 2022-04-10 19:45:00  http://pbs.twimg.com/profile_images/1463665918...
# 5 2022-04-10 19:45:00  http://pbs.twimg.com/profile_images/1507382366...
# 6 2022-04-10 19:45:00  http://pbs.twimg.com/profile_images/1355296710...
#
#        Twitter ID                                         Tweet Text  \
# 0  @Jessica1988kk  RT @invest_answers: Crypto news, #Bitcoin Whal...
# 2      @MmeCallas  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 3        @BotSecx  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 5      @ElTendies  RT @cb_doge: Tesla - A Trillion Dollar Company...
# 6  @LauraCory2013  @elonmusk, few #chargingstations in my area. I...
#
#                                           Tweet Link
# 0  https://twitter.com/Jessica1988kk/status/15131...
# 2  https://twitter.com/MmeCallas/status/151317374...
# 3  https://twitter.com/BotSecx/status/15131737626...
# 5  https://twitter.com/ElTendies/status/151317393...
# 6  https://twitter.com/LauraCory2013/status/15131...

# %%
#get rid of timestamps
tesla_df['Date & Time'] = pd.to_datetime(tesla_df['Date & Time']).dt.date
tesla_df.head()
# Out:
#   Date & Time                               Profile Picture Link  \
# 0  2022-04-10  http://pbs.twimg.com/profile_images/1512074518...
# 2  2022-04-10  http://pbs.twimg.com/profile_images/9364223687...
# 3  2022-04-10  http://pbs.twimg.com/profile_images/1463665918...
# 5  2022-04-10  http://pbs.twimg.com/profile_images/1507382366...
# 6  2022-04-10  http://pbs.twimg.com/profile_images/1355296710...
#
#        Twitter ID                                         Tweet Text  \
# 0  @Jessica1988kk  RT @invest_answers: Crypto news, #Bitcoin Whal...
# 2      @MmeCallas  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 3        @BotSecx  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 5      @ElTendies  RT @cb_doge: Tesla - A Trillion Dollar Company...
# 6  @LauraCory2013  @elonmusk, few #chargingstations in my area. I...
#
#                                           Tweet Link
# 0  https://twitter.com/Jessica1988kk/status/15131...
# 2  https://twitter.com/MmeCallas/status/151317374...
# 3  https://twitter.com/BotSecx/status/15131737626...
# 5  https://twitter.com/ElTendies/status/151317393...
# 6  https://twitter.com/LauraCory2013/status/15131...

# %%
#organize tweets in columns by week

from datetime import datetime, timedelta

start_date = datetime.strptime('2022-04-10', '%Y-%m-%d').date()
end_date = datetime.strptime('2022-04-16', '%Y-%m-%d').date()

final_end_date = datetime.strptime('2022-11-12', '%Y-%m-%d').date()

week_count = 1

dfs = []

while end_date <= final_end_date:
    
    weekly_tweets = tesla_df.loc[(tesla_df['Date & Time'] >= start_date) & 
                                 (tesla_df['Date & Time'] <= end_date), 'Tweet Text']
    weekly_df = weekly_tweets.to_frame().reset_index(drop=True)
    
    week_range = f"Week {week_count} ({start_date.strftime('%m/%d')}-{end_date.strftime('%m/%d')})"
    weekly_df.columns = [week_range]

    dfs.append(weekly_df)

    start_date += timedelta(days=7)
    end_date += timedelta(days=7)
    
    week_count += 1

tesla_df_byweek = pd.concat(dfs, axis=1)

# %%
tesla_df_byweek.head()
# Out:
#                                 Week 1 (04/10-04/16)  \
# 0  RT @invest_answers: Crypto news, #Bitcoin Whal...
# 1  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 2  RT @CottonCodes: 🐒 #love in my #MariaCallas I ...
# 3  RT @cb_doge: Tesla - A Trillion Dollar Company...
# 4  @elonmusk, few #chargingstations in my area. I...
#
#                                 Week 2 (04/17-04/23)  \
# 0  ❎VRR#BNWA-Q9IY-NXLN ❎\nIf you consider buying ...
# 1  RT @EveryElonReply: Elon Musk liked a tweet fr...
# 2  RT @kimpaquette: Todays activity. 😍 #tesla #mo...
# 3  Musk Go-Private Tweet Ruled False by Judge, Te...
# 4  RT @web3_coin: 🎁Buy WEB3COIN IDO to Win a Tesl...
#
#                                 Week 3 (04/24-04/30)  \
# 0  RT @Ali_TeslaMY: Isn’t it ironic that the guy ...
# 1  RT @Ali_TeslaMY: Isn’t it ironic that the guy ...
# 2  RT @Teslaconomics: Fuck him up @elonmusk. 👊\n\...
# 3  RT @Teslaconomics: I bet Wall Street Bets &amp...
# 4  @jhall Bill Gates writes a book called "How to...
#
#                                 Week 4 (05/01-05/07)  \
# 0  RT @JasonDanheiser: $TSLA FSD Beta 10.11.2 dri...
# 1  RT @JasonDanheiser: $TSLA FSD Beta 10.11.2 dri...
# 2  RT @jsongtrades: Buying a Tesla was one of the...
# 3  Is it possible that earth was once two moons o...
# 4  RT @JasonDanheiser: $TSLA FSD Beta 10.11.2 dri...
#
#                                 Week 5 (05/08-05/14)  \
# 0  RT @ElonPromises: "Offer Tesla car insurance w...
# 1  RT @OzobgO: @ZinuNews @elonmusk @ZinuToken Thi...
# 2  RT @JilianneParker: I completely shut down the...
# 3  RT @HermitPossibly: #TRUST AND #INCLUSION ARE ...
# 4  RT @GerberKawasaki: Hey @elonmusk what if we w...
#
#                                 Week 6 (05/15-05/21)  \
# 0  Good job! h8ten was first to spot a 2021 Tesla...
# 1  Whee! h8ten just spotted a 2022 Tesla Model Y ...
# 2  Just posting the stats for this mornings drive...
# 3  Sign Up : Top Stedy #Crypto Platform #Bitcoin ...
# 4  Tesla wouldn’t be successful without Liberals....
#
#                                 Week 7 (05/22-05/28)  \
# 0  RT @JohnRadioTFI: Jeez @EdRadioTFI, we'll have...
# 1  Elon Musk conditions his takeover of Twitter -...
# 2  @spicedrop71 @TheRickWilson Don’t forget the A...
# 3  @netshrink @aliasSubbu Isn't hard cash means c...
# 4  https://t.co/M6a7pBwZY0 @clusterdafrica #europ...
#
#                                 Week 8 (05/29-06/04)  \
# 0  THE F’IN CAR NEEDS THREE NEW TIRES. #tesla BIT...
# 1  Come Tesla in india #Tesla #India $TSLA #Remem...
# 2  RT @EvaFoxU: Tesla jumped 35 positions on the ...
# 3  RT @NodeopolyNFT: #NFTGiveaway coming tomorrow...
# 4  RT @granitacademy: If you post a motivation qu...
#
#                                 Week 9 (06/05-06/11)  \
# 0  Please @JoeBiden please send @elonmusk a check...
# 1  RT @Aiaddict1: #Tesla service rep claims they ...
# 2  RT @BLKMDL3: Model X Plaid beats a Porsche 992...
# 3  #Tesla scores 100/100 for 7th consecutive year...
# 4  RT @BLKMDL3: Model X Plaid beats a Porsche 992...
#
#                                Week 10 (06/12-06/18)  ...  \
# 0  This still seems to be a pretty serious issue ...  ...
# 1  @SimplisticSimon @GonzalesKristie @EvilMopacAT...  ...
# 2  @CryptosGemsCom ⚡ @VoltInuOfficial⚡\n#VOLTINU ...  ...
# 3  RT @_iTsLxght_: @VoltInuOfficial @FTX_Official...  ...
# 4  @DrPepperBlog Doesn't the #tesla logo look lik...  ...
#
#                                Week 22 (09/04-09/10)  \
# 0  RT @Cyberfleet_NFT: TRUCK OF THE DAY\n        ...
# 1  RT @DreamCarClubNFT: Grandpa rides in the fast...
# 2  RT @DreamCarClubNFT: Grandpa rides in the fast...
# 3  RT @MalcolmNance: Treat #CNN like #Tesla. Let’...
# 4  RT @DreamCarClubNFT: Grandpa rides in the fast...
#
#                                Week 23 (09/11-09/17)  \
# 0  #Tesla Solar + #Powerwall more than covers mon...
# 1  RT @Maxlock911: You know what #Tesla , #Amazon...
# 2  @KadakKaspar @CJ_NFA @WPipperger Yeah I am not...
# 3  @VoltInuOfficial @henokcrypto #VOLT #VDSC #VOL...
# 4  RT @stevenmarkryan: https://t.co/NGZB8dP6Us - ...
#
#                                Week 24 (09/18-09/24)  \
# 0  RT @gaspassman: Come on internet, help me catc...
# 1  RT @YOSEquehacer2_: Finanzas con sentido común...
# 2  RT @YOSEquehacer2_: Finanzas con sentido común...
# 3  RT @YOSEquehacer2_: Finanzas con sentido común...
# 4  RT @YOSEquehacer2_: Finanzas con sentido común...
#
#                                Week 25 (09/25-10/01)  \
# 0  @WellsFargo To support, We are launching a mas...
# 1  RT @jotticsgo: @elonmusk To support, We are la...
# 2  @GilbertAZMayor @WellsFargo To support, We are...
# 3  RT @jotticsgo: @WhiteHouse @SecDebHaaland To s...
# 4  RT @jotticsgo: @WhiteHouse @SecDebHaaland To s...
#
#                                Week 26 (10/02-10/08)  \
# 0  RT @Irvings31075139: @WhalePumpCom 🤖🔥 it doesn...
# 1  RT @geniusventures_: Tesla CEO Elon Musk demon...
# 2  RT @goldenkatepark: Who knew the hardest part ...
# 3  RT @Irvings31075139: @nftsonsolana 🤖🔥 it doesn...
# 4  RT @Irvings31075139: @WholeMarsBlog @elonmusk ...
#
#                                Week 27 (10/09-10/15)  \
# 0  RT @amiris_brown: @Just_Hey_JR This sounds lik...
# 1  #bb24 #Ethereum #EthereumMerge #BNB #TRX #TORN...
# 2  @Tesla Semi to begin production of first #Elec...
# 3  A cunning plan indeed… 🤦🏼‍♂️🤣 #matt #tesla #El...
# 4  Contact me if you want to hire me :\nGmail: ta...
#
#                                Week 28 (10/16-10/22)  \
# 0  RT @mvollmer1: Tesla’s Bot 🤖 is going to remov...
# 1  RT @ToddJobson: @elonmusk @KimDotcom @Twitter ...
# 2  RT @GerberKawasaki: Private companies should n...
# 3  RT @EdTowers2022: #Tesla  50% drop in stock va...
# 4  RT @GerberKawasaki: Private companies should n...
#
#                                Week 29 (10/23-10/29)  \
# 0  RT @deanlee4real: @elonmusk @muskQu0tes @elonm...
# 1  RT @NotATeslaApp: Model Y is expected to gener...
# 2  #Bitcoin: #Tesla’s $BTC holding after selling ...
# 3  RT @EvaFoxU: Tesla accelerated its Supercharge...
# 4  RT @mootron: Every once in a while @Nextdoor o...
#
#                                Week 30 (10/30-11/05)  \
# 0  @sarajahgp @Teslarati @WilliamWritin Most peop...
# 1  RT @ClaireMusk: Gary Black says #Tesla's gonna...
# 2  RT @ElonGoatToken: $EGT is busy planning the r...
# 3  So we finally got this question solved once an...
# 4  @PplFuture @SolomonYue @catturd2 @birdymating ...
#
#                                Week 31 (11/06-11/12)
# 0  Let's take a look at #Tesla as an #investment....
# 1  Still waiting for your #Tesla pick-up truck? I...
# 2  @elonmusk @Plinz Is that really you, Elon? It ...
# 3  RT @TechTreesSDG: @elonmusk @kcoleman @ubiquit...
# 4  RT @BaldInvesting: Let's take a look at #Tesla...
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Section 3: Performing the sentiment analysis

# %%
tesla_df.tail()

# %%
tweets = tesla_df["Tweet Text"]
#note - include date
tweets.head()

# %% [markdown]
# ## Sample test of Sentiment Analysis model
#
# Via huggingface and this (https://huggingface.co/blog/sentiment-analysis-twitter) tutorial

# %%
#importing the stuff and definining the analysis function

import requests
model = "cardiffnlp/twitter-roberta-base-sentiment-latest"
hf_token = "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"

API_URL = "https://api-inference.huggingface.co/models/" + model
headers = {"Authorization": "Bearer %s" % (hf_token)}

def analysis(data):
    #function that computes the sentiment
    payload = dict(inputs=data, options=dict(wait_for_model=True))
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

# %%
tweets = tesla_df_byweek["Week 1 (04/10-04/16)"]
tweets_analysis = []

for tweet in tweets:
    if tweet is None:
        break
    try:
        sentiment_result = analysis(tweet)[0]
        top_sentiment = max(sentiment_result, key=lambda x: x['score']) # Get the sentiment with the higher score
        tweets_analysis.append({'tweet': tweet, 'sentiment': top_sentiment['label']})
 
    except Exception as e:
        print(repr(e))
# Out:
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 4>()
#       6     break
#       7 try:
# ----> 8     sentiment_result = analysis(tweet)[0]
#       9     top_sentiment = max(sentiment_result, key=lambda x: x['score']) # Get the sentiment with the higher score
#      10     tweets_analysis.append({'tweet': tweet, 'sentiment': top_sentiment['label']})
#
# Input In [11], in analysis(data)
#      10 def analysis(data):
#      11     #function that computes the sentiment
#      12     payload = dict(inputs=data, options=dict(wait_for_model=True))
# ---> 13     response = requests.post(API_URL, headers=headers, json=payload)
#      14     return response.json()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:117, in post(url, data, json, **kwargs)
#     105 def post(url, data=None, json=None, **kwargs):
#     106     r"""Sends a POST request.
#     107
#     108     :param url: URL for the new :class:`Request` object.
#    (...)
#     114     :rtype: requests.Response
#     115     """
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1038 # Force connect early to allow us to validate the connection.
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#    1043     warnings.warn(
#    1044         (
#    1045             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1050         InsecureRequestWarning,
#    1051     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %%
tweets = tesla_df["Tweet Text"]
tweets_analysis = []

for tweet in tweets:
    try:
        sentiment_result = analysis(tweet)[0]
        top_sentiment = max(sentiment_result, key=lambda x: x['score']) # Get the sentiment with the higher score
        tweets_analysis.append({'tweet': tweet, 'sentiment': top_sentiment['label']})
 
    except Exception as e:
        print(repr(e))
# Out:
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# KeyError(0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       4 for tweet in tweets:
#       5     try:
# ----> 6         sentiment_result = analysis(tweet)[0]
#       7         top_sentiment = max(sentiment_result, key=lambda x: x['score']) # Get the sentiment with the higher score
#       8         tweets_analysis.append({'tweet': tweet, 'sentiment': top_sentiment['label']})
#
# Input In [11], in analysis(data)
#      10 def analysis(data):
#      11     #function that computes the sentiment
#      12     payload = dict(inputs=data, options=dict(wait_for_model=True))
# ---> 13     response = requests.post(API_URL, headers=headers, json=payload)
#      14     return response.json()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:117, in post(url, data, json, **kwargs)
#     105 def post(url, data=None, json=None, **kwargs):
#     106     r"""Sends a POST request.
#     107
#     108     :param url: URL for the new :class:`Request` object.
#    (...)
#     114     :rtype: requests.Response
#     115     """
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1038 # Force connect early to allow us to validate the connection.
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#    1043     warnings.warn(
#    1044         (
#    1045             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1050         InsecureRequestWarning,
#    1051     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
print(sentiment_result)

# %%
# for i in range(10):
#     print(tweets[i])
#     print('\n')
print(tweets[1])

# %%
#sanity check

tweets2 = tweets[0:1]
tweets2[1] = "Tesla has a record for cars sold. It's impressive, but it never ceases to amaze me that by selling 6 times less units than Toyota, for example, Tesla is worth 3 or 4 times more. https://t.co/u7Jm8oS54t via @Inoreader"
print(tweets2)

print(analysis(tweets2[1])[0])
